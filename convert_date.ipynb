# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.offline as py
import plotly.express as px
import scipy.stats as st

# %%
filepath = "USdata.csv"
usdata=pd.read_csv(filepath)
usdata.head(10)
# Out:
#   Country Province/State   Latitude   Longitude  Confirmed  Recovered  Deaths  \
# 0      US     Washington  47.140037 -120.791360        1.0        NaN     NaN
# 1      US     Washington  47.140037 -120.791360        1.0        NaN     NaN
# 2      US     Washington  47.140037 -120.791360        1.0        NaN     NaN
# 3      US        Chicago  38.212678  -89.502995        1.0        NaN     NaN
# 4      US     Washington  47.140037 -120.791360        1.0        NaN     NaN
# 5      US       Illinois  39.860649  -89.130850        1.0        NaN     NaN
# 6      US     Washington  47.140037 -120.791360        1.0        NaN     NaN
# 7      US       Illinois  39.860649  -89.130850        1.0        NaN     NaN
# 8      US     California  37.938993 -120.997072        2.0        NaN     NaN
# 9      US        Arizona  33.348359 -111.344948        1.0        NaN     NaN
#
#         Date
# 0  1/22/2020
# 1  1/23/2020
# 2  1/24/2020
# 3  1/24/2020
# 4  1/25/2020
# 5  1/25/2020
# ...

# %%
datagroupby=usdata.groupby(['Date','Confirmed'])
datagroupby.sum()
# Out:
#                        Latitude   Longitude  Recovered   Deaths
# Date      Confirmed
# 1/22/2020 1.0         47.140037 -120.791360        0.0      0.0
# 1/23/2020 1.0         47.140037 -120.791360        0.0      0.0
# 1/24/2020 1.0         85.352715 -210.294354        0.0      0.0
# 1/25/2020 1.0         87.000686 -209.922210        0.0      0.0
# 1/26/2020 1.0        120.349045 -321.267158        0.0      0.0
# ...                         ...         ...        ...      ...
# 7/9/2020  55961.0     25.611236  -80.551706        0.0   1092.0
#           73165.0     33.348359 -112.491815        0.0   1012.0
#           94005.0     41.841448  -87.816588        0.0   4676.0
#           124992.0    34.308284 -118.228241        0.0   3690.0
#           218052.0    40.767273  -73.971526        0.0  23247.0
#
# [87616 rows x 4 columns]

# %%
datagroupby=usdata.groupby(['Date']).sum()
datagroupby.head()
# Out:
#              Latitude   Longitude  Confirmed  Recovered  Deaths
# Date
# 1/22/2020   47.140037 -120.791360        1.0        0.0     0.0
# 1/23/2020   47.140037 -120.791360        1.0        0.0     0.0
# 1/24/2020   85.352715 -210.294354        2.0        0.0     0.0
# 1/25/2020   87.000686 -209.922210        2.0        0.0     0.0
# 1/26/2020  158.288038 -442.264230        5.0        0.0     0.0

# %%
datagroupby.to_csv(r'gbyusdata.csv')

# %%
list(usdata['Province/State'])
# Out:
# ['Washington',
#  'Washington',
#  'Washington',
#  'Chicago',
#  'Washington',
#  'Illinois',
#  'Washington',
#  'Illinois',
#  'California',
#  'Arizona',
#  'Washington',
#  'Illinois',
#  'California',
#  'Arizona',
#  'Washington',
#  'Illinois',
#  'California',
#  'Arizona',
#  'Washington',
#  'Illinois',
#  'California',
#  'Arizona',
#  'Washington',
#  'Illinois',
#  'California',
#  'Arizona',
#  'Illinois',
#  'California',
#  'Washington',
#  'Arizona',
#  'Chicago, IL',
#  'Boston, MA',
#  'Los Angeles, CA',
#  'Orange, CA',
#  'Santa Clara, CA',
#  'Seattle, WA',
#  'Tempe, AZ',
#  'Chicago, IL',
#  'Boston, MA',
#  'Los Angeles, CA',
#  'Orange, CA',
#  'Santa Clara, CA',
#  'Seattle, WA',
#  'Tempe, AZ',
#  'Chicago, IL',
#  'San Benito, CA',
#  'Santa Clara, CA',
#  'Boston, MA',
#  'Los Angeles, CA',
#  'Orange, CA',
#  'Seattle, WA',
#  'Tempe, AZ',
#  'Chicago, IL',
#  'San Benito, CA',
#  'Santa Clara, CA',
#  'Boston, MA',
#  'Los Angeles, CA',
# ...

# %%
ill=data[data["Province/State"]=='Illinois']
ill0=ill.groupby(['Date']).sum()
ill0
# Out:
#               Latitude    Longitude  Confirmed  Recovered  Deaths
# Date
# 1/25/2020    39.860649   -89.130850        1.0        0.0     0.0
# 1/26/2020    39.860649   -89.130850        1.0        0.0     0.0
# 1/27/2020    39.860649   -89.130850        1.0        0.0     0.0
# 1/28/2020    39.860649   -89.130850        1.0        0.0     0.0
# 1/29/2020    39.860649   -89.130850        1.0        0.0     0.0
# ...                ...          ...        ...        ...     ...
# 7/5/2020   4143.770304 -9274.451367   147251.0        0.0  7020.0
# 7/6/2020   4143.770304 -9274.451367   147865.0        0.0  7026.0
# 7/7/2020   4143.770304 -9274.451367   149574.0        0.0  7273.0
# 7/8/2020   4143.770304 -9274.451367   150554.0        0.0  7309.0
# 7/9/2020   4143.770304 -9274.451367   151572.0        0.0  7329.0
#
# [143 rows x 5 columns]

# %%
cal=data[data["Province/State"]=='California']
#cal0=cal.groupby(['Date']).sum()
#cal0
cal
# Out:
#        Country Province/State   Latitude   Longitude  Confirmed  Recovered  \
# 8           US     California  37.938993 -120.997072        2.0        NaN
# 12          US     California  37.938993 -120.997072        2.0        NaN
# 16          US     California  37.938993 -120.997072        2.0        NaN
# 20          US     California  37.938993 -120.997072        2.0        NaN
# 24          US     California  37.938993 -120.997072        2.0        NaN
# ...        ...            ...        ...         ...        ...        ...
# 370737      US     California  38.026440 -119.952509      109.0        0.0
# 370755      US     California  37.938993 -120.997072        0.0        0.0
# 370844      US     California  34.444657 -119.091061     6156.0        0.0
# 371082      US     California  38.682789 -121.901829     1275.0        0.0
# 371089      US     California  39.262559 -121.353564      319.0        0.0
#
#         Deaths       Date
# 8          NaN  1/26/2020
# ...

# %%
dfdate= usdata['Date'].astype(str).str.split('/',expand=True)
dfdate.columns = ['month','date','year']

# %%
df=pd.concat([usdata,dfdate],axis=1)
df
# Out:
#        Country  Province/State   Latitude   Longitude  Confirmed  Recovered  \
# 0           US      Washington  47.140037 -120.791360        1.0        NaN
# 1           US      Washington  47.140037 -120.791360        1.0        NaN
# 2           US      Washington  47.140037 -120.791360        1.0        NaN
# 3           US         Chicago  38.212678  -89.502995        1.0        NaN
# 4           US      Washington  47.140037 -120.791360        1.0        NaN
# ...        ...             ...        ...         ...        ...        ...
# 371101      US  Virgin Islands  18.335800  -64.896300      336.0        0.0
# 371102      US        Oklahoma  35.542606  -97.068263        0.0        0.0
# 371103      US          Alaska  59.796037 -158.238194        1.0        0.0
# 371104      US           Idaho  46.233153 -116.434146        1.0        0.0
# 371105      US          Oregon  44.726982 -120.028143        0.0        0.0
#
#         Deaths       Date month date  year
# ...

# %%
jan=ill=df[df["month"]=='1']
jan
# Out:
#    Country Province/State   Latitude   Longitude  Confirmed  Recovered  \
# 0       US     Washington  47.140037 -120.791360        1.0        NaN
# 1       US     Washington  47.140037 -120.791360        1.0        NaN
# 2       US     Washington  47.140037 -120.791360        1.0        NaN
# 3       US        Chicago  38.212678  -89.502995        1.0        NaN
# 4       US     Washington  47.140037 -120.791360        1.0        NaN
# 5       US       Illinois  39.860649  -89.130850        1.0        NaN
# 6       US     Washington  47.140037 -120.791360        1.0        NaN
# 7       US       Illinois  39.860649  -89.130850        1.0        NaN
# 8       US     California  37.938993 -120.997072        2.0        NaN
# 9       US        Arizona  33.348359 -111.344948        1.0        NaN
# 10      US     Washington  47.140037 -120.791360        1.0        NaN
# 11      US       Illinois  39.860649  -89.130850        1.0        NaN
# ...

# %%
Feb=df[df["month"]=='2']
Feb
# Out:
#     Country                        Province/State  Latitude  Longitude  \
# 30       US                           Chicago, IL   41.8781   -87.6298
# 31       US                            Boston, MA   42.3601   -71.0589
# 32       US                       Los Angeles, CA   34.0522  -118.2437
# 33       US                            Orange, CA   33.7879  -117.8531
# 34       US                       Santa Clara, CA   37.3541  -121.9552
# ..      ...                                   ...       ...        ...
# 369      US                  Snohomish County, WA   48.0330  -121.8339
# 370      US                             Tempe, AZ   33.4255  -111.9400
# 371      US  Lackland, TX (From Diamond Princess)   29.3829   -98.6134
# 372      US     Omaha, NE (From Diamond Princess)   41.2545   -95.9758
# 373      US    Travis, CA (From Diamond Princess)   38.2721  -121.9399
#
#      Confirmed  Recovered  Deaths       Date month date  year
# ...

# %%
Mar=df[df["month"]=='3']
Mar
# Out:
#       Country                               Province/State  Latitude  \
# 374        US  Unassigned Location (From Diamond Princess)   35.4437
# 375        US                                  Seattle, WA   47.6062
# 376        US                                  Chicago, IL   41.8781
# 377        US                              Santa Clara, CA   37.3541
# 378        US                        Sacramento County, CA   38.4747
# ...       ...                                          ...       ...
# 32344      US                                         Guam   13.4443
# 32345      US                     Northern Mariana Islands   15.0979
# 32346      US                                  Puerto Rico   18.2208
# 32347      US                                    Recovered    0.0000
# 32348      US                               Virgin Islands   18.3358
#
#        Longitude  Confirmed  Recovered  Deaths       Date month date  year
# ...

# %%
Apr=df[df["month"]=='4']
Apr
# Out:
#        Country            Province/State   Latitude   Longitude  Confirmed  \
# 32349       US            South Carolina  34.223334  -82.461707        4.0
# 32350       US                 Louisiana  30.295065  -92.414197       47.0
# 32351       US                  Virginia  37.767072  -75.632346        7.0
# 32352       US                     Idaho  43.452658 -116.241552      195.0
# 32353       US                      Iowa  41.330756  -94.471059        1.0
# ...        ...                       ...        ...         ...        ...
# 113675      US                      Guam  13.444300  144.793700      145.0
# 113676      US  Northern Mariana Islands  15.097900  145.673900       14.0
# 113677      US               Puerto Rico  18.220800  -66.590100     1539.0
# 113678      US                 Recovered   0.000000    0.000000        0.0
# 113679      US            Virgin Islands  18.335800  -64.896300       66.0
#
#         Recovered  Deaths       Date month date  year
# ...

# %%
May=df[df["month"]=='5']
May
# Out:
#        Country            Province/State   Latitude   Longitude  Confirmed  \
# 113680      US            South Carolina  34.223334  -82.461707       31.0
# 113681      US                 Louisiana  30.295065  -92.414197      133.0
# 113682      US                  Virginia  37.767072  -75.632346      303.0
# 113683      US                     Idaho  43.452658 -116.241552      681.0
# 113684      US                      Iowa  41.330756  -94.471059        1.0
# ...        ...                       ...        ...         ...        ...
# 206168      US                      Guam  13.444300  144.793700      172.0
# 206169      US  Northern Mariana Islands  15.097900  145.673900       22.0
# 206170      US               Puerto Rico  18.220800  -66.590100     3776.0
# 206171      US                 Recovered   0.000000    0.000000        0.0
# 206172      US            Virgin Islands  18.335800  -64.896300       69.0
#
#         Recovered  Deaths       Date month date  year
# ...

# %%
June = May=df[df["month"]=='6']
June
# Out:
#        Country            Province/State   Latitude   Longitude  Confirmed  \
# 206173      US            South Carolina  34.223334  -82.461707       44.0
# 206174      US                 Louisiana  30.295065  -92.414197      422.0
# 206175      US                  Virginia  37.767072  -75.632346      917.0
# 206176      US                     Idaho  43.452658 -116.241552      812.0
# 206177      US                      Iowa  41.330756  -94.471059        9.0
# ...        ...                       ...        ...         ...        ...
# 298344      US                      Guam  13.444300  144.793700      257.0
# 298345      US  Northern Mariana Islands  15.097900  145.673900       30.0
# 298346      US               Puerto Rico  18.220800  -66.590100     7465.0
# 298347      US                 Recovered   0.000000    0.000000        0.0
# 298348      US            Virgin Islands  18.335800  -64.896300       81.0
#
#         Recovered  Deaths       Date month date  year
# ...

# %%
July = May=df[df["month"]=='7']
July
# Out:
#        Country  Province/State   Latitude   Longitude  Confirmed  Recovered  \
# 298349      US  South Carolina  34.223334  -82.461707      113.0        0.0
# 298350      US       Louisiana  30.295065  -92.414197      919.0        0.0
# 298351      US        Virginia  37.767072  -75.632346     1043.0        0.0
# 298352      US           Idaho  43.452658 -116.241552     2288.0        0.0
# 298353      US            Iowa  41.330756  -94.471059       15.0        0.0
# ...        ...             ...        ...         ...        ...        ...
# 371101      US  Virgin Islands  18.335800  -64.896300      336.0        0.0
# 371102      US        Oklahoma  35.542606  -97.068263        0.0        0.0
# 371103      US          Alaska  59.796037 -158.238194        1.0        0.0
# 371104      US           Idaho  46.233153 -116.434146        1.0        0.0
# 371105      US          Oregon  44.726982 -120.028143        0.0        0.0
#
#         Deaths       Date month date  year
# ...
